# %% [markdown]
# ## Assigning plate ids to features
#
# To reconstruct any feature geometries, each feature must have a plate id assigned. If they don't already, then the pygplates function 'PlatePartitioner' performs this function (analogous to the 'assign plate ids' menu option in GPlates GUI)
#
# In the first example, we partition magnetic anomaly picks from the Global Seafloor Fabric and Magnetic Lineation Database (or GSFML): http://www.soest.hawaii.edu/PT/GSFML/
#
# Magnetic picks from this database can be downloaded in GPlates-friendly data formats - however, none of the points are associated with any particular plate tectonic reconstruction or plate id system. Hence, to be able to reconstruct these points, we need to assign the plate id to each point ourselves. This involves using the 'Static Polygons' - for an overview, look at the 'Creating Features' tutorial for GPlates: https://sites.google.com/site/gplatestutorials/

# %%
import pygplates

# The magnetic picks are the 'features to partition'
# Since they are already in OGR GMT format, gplates can read them directly 
mag_picks = pygplates.FeatureCollection('Data/GSFML.Gaina++_2009_JGeolSoc.picks.gmt')

# static polygons are the 'partitioning features'
static_polygons = pygplates.FeatureCollection('Data/Seton_etal_ESR2012_StaticPolygons_2012.1.gpmlz')

# The partition_into_plates function requires a rotation model, since sometimes this would be
# necessary even at present day (for example to resolve topological polygons)
rotation_model=pygplates.RotationModel('Data/Seton_etal_ESR2012_2012.1.rot')

# partition features
partitioned_mag_picks = pygplates.partition_into_plates(static_polygons,
                                                       rotation_model,
                                                       mag_picks)

# Write the partitioned data set to a file
output_feature_collection = pygplates.FeatureCollection(partitioned_mag_picks)
output_feature_collection.write('/tmp/GSFML.Gaina++_2009_JGeolSoc.picks.partitioned.gmt')

# %% [markdown]
# As a second example, we take a dataset that currently could not be loaded directly into gplates (since it is not in a gplates-readable format).
#
# The points are paleoenvironmental indicators from a map compilation by Boucot et al (2013), downloaded in from Christopher Scotese's rsearchgate page in csv format (all data are lat,long points with a series of other attributes).
#
# There are a number of ways to deal with this data in python, here we use a pandas dataframe

# %%
import pandas as pd

df = pd.read_csv('Data/Boucot_etal_Map24_Paleocene_v4.csv',sep=',')

df
# Out:
#     LithologyCode  LithNumber OldIDNumber  Unnamed: 3    LAT NS    LONG EW  \
# 0               E           1       E5466         NaN  29.00  N   17.00  E
# 1               E           2       E5467         NaN  28.00  N   22.00  E
# 2               E           3       E5468         NaN  28.00  N   17.00  E
# 3               E           4       E5469         NaN  28.00  N   18.00  E
# 4               E           5     E5469.1         NaN  31.00  N   21.00  E
# 5               E           6       E5470         NaN  32.00  N   -7.00  W
# 6               E           7       E5471         NaN  13.00  N    6.00  E
# 7               E           8     E5471.1         NaN  15.00  N    5.50  E
# 8               E           9       E5472         NaN   5.00  N   47.00  E
# 9               E          10     E5472.1         NaN -33.00  S   28.00  E
# 10              E          11     E5472.2         NaN  34.30  N    8.50  E
# 11              E          12       E5473         NaN  40.00  N   75.00  E
# 12              E          13       E5474         NaN  39.00  N   80.00  E
# 13              E          14       E5475         NaN  41.50  N   81.50  E
# 14              E          15       E5476         NaN  33.00  N  119.00  E
# 15              E          16       E5477         NaN  36.00  N  117.00  E
# 16              E          17       E5478         NaN  35.00  N  116.50  E
# 17              E          18       E5479         NaN  31.25  N  114.00  E
# 18              E          19       E5480         NaN  29.50  N  112.00  E
# 19              E          20       E5481         NaN  30.50  N  113.00  E
# 20              E          21       E5482         NaN  28.00  N  115.50  E
# 21              E          22       E5483         NaN  27.00  N  112.50  E
# 22              E          23       E5484         NaN  23.00  N  101.00  E
# 23              E          24     E5484.1         NaN  30.10  N  103.00  E
# 24              E          25     E5484.2         NaN  29.90  N  102.90  E
# 25              E          26     E5484.3         NaN  29.90  N  103.30  E
# 26              E          27     E5484.4         NaN  31.70  N  119.50  E
# 27              E          28       E5485         NaN  22.50  N  101.50  E
# 28              E          29       E5486         NaN  26.50  N   99.50  E
# 29              E          30       E5487         NaN  26.00  N  100.00  E
# ..            ...         ...         ...         ...    ... ..     ... ..
# 232             K         233       K5642         NaN  41.00  N   -5.50  W
# 233             K         234       K5643         NaN  51.00  N   -4.00  W
# 234             K         235       K5644         NaN  80.00  N  -87.00  W
# 235             K         236     K5644.1         NaN  53.00  N -110.00  W
# 236             K         237     K5644.2         NaN  70.00  N  -53.00  E
# 237             K         238     K5644.3         NaN  31.00  N  -85.00  W
# 238             K         239       K5645         NaN  34.00  N -117.50  W
# 239             K         240       K5646         NaN  33.50  N -117.00  W
# 240             K         241       K5647         NaN  33.00  N  -84.75  W
# 241             K         242     K5647.1         NaN  38.00  N  -78.00  W
# 242             K         243       K5648         NaN  46.00  N -108.00  W
# 243             K         244       K5649         NaN  36.75  N -105.00  W
# 244             K         245       K5650         NaN -26.00  S  -49.00  W
# 245             L         246     L5650.2         NaN  21.20  N   41.50  E
# 246             L         247     L5650.3         NaN  17.50  N   18.25  E
# 247             L         248     L5650.1         NaN  16.50  N   43.00  E
# 248             L         249       L5651         NaN  57.00  N   -6.00  W
# 249             L         250       L5652         NaN  57.50  N    6.50  W
# 250             L         251     L5652.1         NaN  -6.00  S  -49.00  W
# 251            PA         252      Pa5653         NaN  72.00  N  -52.00  W
# 252            PA         253    Pa5653.1         NaN  62.00  N -149.00  W
# 253            PA         254      Pa5654         NaN  48.50  N -122.00  W
# 254            PA         255      Pa5655         NaN -50.00  S  -69.00  W
# 255             M         256       M5657         NaN -43.00  S  146.00  E
# 256             M         257     M5657.1         NaN  47.00  N   14.00  E
# 257             M         258       M5658         NaN -46.00  S  170.00  E
# 258            CR         259      Cr5659         NaN  56.00  N   13.00  E
# 259            CR         260    Cr5659.1         NaN  48.75  N   44.50  E
# 260            CR         261      Cr5660         NaN  51.00  N -114.00  W
# 261            CR         262      Cr5661         NaN -41.50  S  -66.00  W
#
#          Continent            Country  ...  \
# 0           Africa              Libya  ...
# 1           Africa              Libya  ...
# 2           Africa              Libya  ...
# 3           Africa              Libya  ...
# 4           Africa              Libya  ...
# 5           Africa            Morocco  ...
# 6           Africa            Nigeria  ...
# 7           Africa            Nigeria  ...
# 8           Africa            Somalia  ...
# 9           Africa       South Africa  ...
# 10          Africa            Tunisia  ...
# 11            Asia              China  ...
# 12            Asia              China  ...
# 13            Asia              China  ...
# 14            Asia              China  ...
# 15            Asia              China  ...
# 16            Asia              China  ...
# 17            Asia              China  ...
# 18            Asia              China  ...
# 19            Asia              China  ...
# 20            Asia              China  ...
# 21            Asia              China  ...
# 22            Asia              China  ...
# 23            Asia              China  ...
# 24            Asia              China  ...
# 25            Asia              China  ...
# 26            Asia              China  ...
# 27            Asia              China  ...
# 28            Asia              China  ...
# 29            Asia              China  ...
# ..             ...                ...  ...
# 232         Europe              Spain  ...
# 233         Europe     United Kingdom  ...
# 234  North America             Canada  ...
# 235  North America             Canada  ...
# 236  North America          Greenland  ...
# 237  North America      United States  ...
# 238  North America      United States  ...
# 239  North America      United States  ...
# 240  North America      United States  ...
# 241  North America      United States  ...
# 242  North America      United States  ...
# 243  North America      United States  ...
# 244  South America             Brazil  ...
# 245           Asia       Saudi Arabia  ...
# 246           Asia       Saudi Arabia  ...
# 247           Asia  Republic of Yemen  ...
# 248         Europe     United Kingdom  ...
# 249         Europe     United Kingdom  ...
# 250  South America             Brazil  ...
# 251  North America          Greenland  ...
# 252  North America      United States  ...
# 253  North America      United States  ...
# 254  South America          Argentina  ...
# 255      Australia                NaN  ...
# 256         Europe            Austria  ...
# 257         Europe        New Zealand  ...
# 258         Europe             Sweden  ...
# 259         Europe             Russia  ...
# 260  North America             Canada  ...
# 261  South America          Argentina  ...
#
#                                           GeogComments       LMU     Period  \
# 0                                                  NaN     Lower  Paleogene
# 1                                          Sirte Basin     Lower  Paleogene
# 2                                          Sirte Basin     Lower  Paleogene
# 3                                                  NaN     Lower  Paleogene
# 4                                   Al Jabar al Akhdar     Lower  Paleogene
# 5                                                  NaN     Lower  Paleogene
# 6                                 northwestern Nigeria     Lower  Paleogene
# 7                                         Sokoto Basin     Lower  Paleogene
# 8                                      coastal Somalia     Lower  Paleogene
# 9                                            Fort Gray     Lower  Paleogene
# 10                                     Metlaoui region     Lower  Paleogene
# 11                              Northwest China:Wuchai     Lower  Paleogene
# 12                            Northwest China:Mazatake     Lower  Paleogene
# 13                        Northwest China:Wenshu-Kuche     L - M  Paleogene
# 14                                 North China:Hongzhe     L - M  Paleogene
# 15                               North China:Daewenkou     Lower  Paleogene
# 16                                North China:Fengxian     Lower  Paleogene
# 17                        South China:Yunmeng-Yincheng     L - M  Paleogene
# 18                                  South China:Lixian     L - M  Paleogene
# 19                               South China:Qianjiang     Lower  Paleogene
# 20                               South China:Qingjiang     Lower  Paleogene
# 21                               South China:Qingjiang     L - M  Paleogene
# 22                            South China:Simao,Yunnan     Lower  Paleogene
# 23                        South China:Sichuan-Mingshan     L - M  Paleogene
# 24                           South China:Sichuan-Yanan     L - M  Paleogene
# 25                          South China:Sichuan-Hongya     L - M  Paleogene
# 26                                  South China:Jintan     Lower  Paleogene
# 27      Tibet and Western Yunnan:Simao-Jiangcheng area     Lower  Paleogene
# 28                    Tibet and Western Yunnan:Lanping     Lower  Paleogene
# 29                     Tibet and Western Yunnan:Eryuan     Lower  Paleogene
# ..                                                 ...       ...        ...
# 232                                                NaN     Lower  Paleogene
# 233                                      England:Devon     Lower  Paleogene
# 234                                             Arctic     Lower  Paleogene
# 235                 Saskatchewan:southern Saskatchewan  L  -M-U?  Paleogene
# 236                                     West Greenland     Lower  Paleogene
# 237                   Alabama:near Fort Gaines,Georgia     Lower  Paleogene
# 238                                California:Aberhill  L  -M-U?  Paleogene
# 239  California:Orange County,in the Santa Ana Moun...  L  -M-U?  Paleogene
# 240                               Georgia:Warm Springs     Lower  Paleogene
# 241                       New Jersey,Martland,Virginia     L - M  Paleogene
# 242                              Montana:Tullock Creek  L  -M-U?  Paleogene
# 243         New Mexico:Raton Coal Field, Colfax County  L  -M-U?  Paleogene
# 244                                southeastern Brazil     Lower  Paleogene
# 245                                                NaN     Lower  Paleogene
# 246                          southwestern Saudi Arabia     Lower  Paleogene
# 247                                                NaN     L - M  Paleogene
# 248                                     Inner Hebrides  L  -M-U?  Paleogene
# 249                                      northern Skye  L  -M-U?  Paleogene
# 250                               500km south of Belem     Lower  Paleogene
# 251                                 Nugssuak Peninsula     Lower  Paleogene
# 252                                             Alaska     Lower  Paleogene
# 253              Washington:near Bellingham,Washington  L  -M-U?  Paleogene
# 254                 Cerro Abigrrado in Chubut Province     Lower  Paleogene
# 255                                           Tanmania  L  -M-U?  Paleogene
# 256                    Carinthia in the Krappfeld area  L  -M-U?  Paleogene
# 257                                       South Island  L  -M-U?  Paleogene
# 258                                            Limhamm     Lower  Paleogene
# 259                                   Volgograd region  L  -M-U?  Paleogene
# 260                                Alberta:Elbow River  L  -M-U?  Paleogene
# 261                                             Chubut     M - L  Paleogene
#
#       Stage                      AgeComments            Lithology  \
# 0       NaN                              NaN           Evaporites
# 1       NaN                              NaN           Evaporites
# 2       NaN                          Montian           Evaporites
# 3       NaN                          Montian           Evaporites
# 4       NaN                   Late Paleocene           Evaporites
# 5       NaN                        Paleocene           Evaporites
# 6       NaN                              NaN               Gypsum
# 7       NaN                        Paleocene           Evaporites
# 8       NaN                        Paleocene           Evaporites
# 9       NaN                        Paleocene           Evaporites
# 10      NaN                              NaN           Evaporites
# 11      NaN                        Paleocene           Evaporites
# 12      NaN                        Paleocene           Evaporites
# 13      NaN              Paleocene to Eocene           Evaporites
# 14      NaN        Paleocene to early Eocene           Evaporites
# 15      NaN                        Paleocene               Gypsum
# 16      NaN                        Paleocene               Gypsum
# 17      NaN        Paleocene to early Eocene           Evaporites
# 18      NaN        Paleocene to early Eocene           Evaporites
# 19      NaN                        Paleocene           Evaporites
# 20      NaN                        Paleocene           Evaporites
# 21      NaN                 Paleocene-Eocene           Evaporites
# 22      NaN                              NaN           Evaporites
# 23      NaN              Paleocene to Eocene           Evaporites
# 24      NaN              Paleocene to Eocene           Evaporites
# 25      NaN              Paleocene to Eocene           Evaporites
# 26      NaN                        Paleocene           Evaporites
# 27      NaN                        Paleocene           Evaporites
# 28      NaN                        Paleocene           Evaporites
# 29      NaN                        Paleocene           Evaporites
# ..      ...                              ...                  ...
# 232     NaN            beneath the Paleocene           Kaolinites
# 233     NaN                        Paleocene           Kaolinites
# 234     NaN                        Paleocene           Kaolinites
# 235     NaN                              NaN           Kaolinites
# 236     NaN                        Paleocene           Kaolinites
# 237     NaN                   Late Paleocene           Kaolinites
# 238     NaN                              NaN           Kaolinites
# 239     NaN                              NaN           Kaolinites
# 240     NaN                   Late Paleocene           Kaolinites
# 241     NaN  Late Paleocene and early Eocene           Kaolinites
# 242     NaN                         Tertiary           Kaolinites
# 243     NaN                              NaN           Kaolinites
# 244     NaN                        Paleocene           Kaolinites
# 245     NaN                        Paleocene       Lateritic Beds
# 246     NaN                        Paleocene       Lateritic Beds
# 247     NaN   late Paleocene or early Eocene       Lateritic Beds
# 248     NaN                              NaN       Lateritic Beds
# 249     NaN                              NaN       Lateritic Beds
# 250     NaN   Late Cretaceous to the Miocene  Lateritic Manganese
# 251  Danian                        Paleocene                Palms
# 252     NaN                        Paleocene                Palms
# 253     NaN                              NaN                Palms
# 254  Danian                        Paleocene                Palms
# 255     NaN                              NaN            Mangroves
# 256     NaN                              NaN            Mangroves
# 257     NaN                              NaN            Mangroves
# 258  Danian                        Paleocene         Crocodilians
# 259     NaN                              NaN         Crocodilians
# 260     NaN                              NaN         Crocodilians
# 261     NaN                        Paleocene         Crocodilians
#
#                                         Formation  \
# 0                                        Hofra(?)
# 1                                             NaN
# 2                                             NaN
# 3                                   Beda Dolomite
# 4                                             NaN
# 5                                             NaN
# 6                                 Thanetian Dange
# 7                         Unit B of Paleocene age
# 8                                             NaN
# 9                                          Knysna
# 10                                         Tselja
# 11                                            NaN
# 12                                            NaN
# 13                                            NaN
# 14                                         Funing
# 15                                     Guanzhuang
# 16                                     Guanzhuang
# 17                                            NaN
# 18                                            NaN
# 19                                            NaN
# 20                                      Qingjiang
# 21                                       Hengyang
# 22                                      Mengyjing
# 23                                       Mingshan
# 24                                       Mingshan
# 25                                       Mingshan
# 26                                         Funing
# 27                                            NaN
# 28                                            NaN
# 29                                            NaN
# ..                                            ...
# 232                                           NaN
# 233                                           NaN
# 234                                  Eureka Sound
# 235                                    Ravenscrag
# 236                                           NaN
# 237                                  Baker Hill
# 238                                           NaN
# 239                                      Martinez
# 240                           Republic Mines Beds
# 241                        Coastal Plain sequence
# 242                                           NaN
# 243                                        Raton
# 244                                           NaN
# 245                 lower member of the Umm Jimar
# 246                                           NaN
# 247                                Madak Laterite
# 248                                           NaN
# 249                                           NaN
# 250                                           NaN
# 251                                       Agatdal
# 252                                           NaN
# 253  Chuckanut Frm, older part of the Puget Group
# 254                                     Salamanca
# 255                                           NaN
# 256                                           NaN
# 257                                           NaN
# 258                                           NaN
# 259                                           NaN
# 260                                           NaN
# 261                                           NaN
#
#                                         LithComments  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                      in well DI-41
# 5                                                NaN
# 6                                                NaN
# 7                                                NaN
# 8                                                NaN
# 9                                                NaN
# 10                                               NaN
# 11                              gypsum and rock salt
# 12                              gypsum and rock salt
# 13                                        gypsum ore
# 14                                          salt ore
# 15                                               NaN
# 16                                               NaN
# 17                                         rock salt
# 18                                         rock salt
# 19                                         rock salt
# 20                        rock salt ore(with gypsum)
# 21                        rock salt ore(with gypsum)
# 22                                               NaN
# 23                                               NaN
# 24                                               NaN
# 25                                               NaN
# 26                                               NaN
# 27                                   potash salt ore
# 28                                    rock salt ore
# 29                                     rock salt ore
# ..                                               ...
# 232                                              NaN
# 233                                          kaolins
# 234                                              NaN
# 235                                              NaN
# 236            kaolinitic sediments in the nonmarine
# 237                             kaolinitic sediments
# 238                                              NaN
# 239                                              NaN
# 240                              with minor gibbsite
# 241                                  detrital kaolin
# 242                                         tonstein
# 243                               Raton Frm tonstein
# 244                                              NaN
# 245                                              NaN
# 246  Hadley et al.(1983), cite the As Sarat laterite
# 247                                              NaN
# 248                                              NaN
# 249                              lateritic materials
# 250                                              NaN
# 251                                              NaN
# 252                                              NaN
# 253                                              NaN
# 254                           Palmoxylon patagonicum
# 255                                      Nypa pollen
# 256                                      Nypa pollen
# 257                                      Nypa pollen
# 258                                              NaN
# 259                                              NaN
# 260                                              NaN
# 261                                              NaN
#
#                                       PrimaryReference  \
# 0                                Claypool et al.(1980)
# 1                              Gillespie,Sanford(1967)
# 2                                      Abushagur(1992)
# 3                              Garea,Braithwaite(1996)
# 4                                    Abdul-Samad(2000)
# 5                                         Salvan(1972)
# 6                                        Petters(1979)
# 7                                           Alam(1986)
# 8                                         Barnes(1976)
# 9                                  Dingle et al.(1983)
# 10                               Moody,Buffetaut(1981)
# 11                                   Chu Xu-chun(1986)
# 12                                   Chu Xu-chun(1986)
# 13                                   Chu Xu-chun(1986)
# 14                                   Chu Xu-chun(1986)
# 15                                   Chu Xu-chun(1986)
# 16                                   Chu Xu-chun(1986)
# 17                                   Chu Xu-chun(1986)
# 18                                   Chu Xu-chun(1986)
# 19                                   Chu Xu-chun(1986)
# 20                                   Chu Xu-chun(1986)
# 21                                   Chu Xu-chun(1986)
# 22                                  Wei Dong-yan(1991)
# 23                  Wang Meng-jun,Zeng Liang-kui(1982)
# 24                  Wang Meng-jun,Zeng Liang-kui(1982)
# 25                  Wang Meng-jun,Zeng Liang-kui(1982)
# 26                        Xu Xue-si,Hu Lian-ying(2000)
# 27                                   Chu Xu-chun(1986)
# 28                                   Chu Xu-chun(1986)
# 29                                   Chu Xu-chun(1986)
# ..                                                 ...
# 232                                Molina,Blanco(1980)
# 233                                        Isaac(1983)
# 234                               Bustin,Bayliss(1979)
# 235                                       Guliov(1984)
# 236                              Pedersen et al.(1998)
# 237                                       Gibson(1992)
# 238                             Murray,Patterson(1975)
# 239                            Turner(1957, in Wright)
# 240                             Reinhardt et al.(1984)
# 241                                Gibson et al.(2000)
# 242                                  Burger(1978-1980)
# 243                               Bohor,Pillmore(1976)
# 244                             Riccomini et al.(1996)
# 245                              Whitmore,Madden(1995)
# 246        Coleman(1993, Fig. 2.6),Hadley et al.(1983)
# 247                                 Kruck et al.(1996)
# 248                               Emeleus et al.(1996)
# 249                                  Bell et al.(1996)
# 250                                Ruffet et al.(1996)
# 251                                         Koch(1972)
# 252                                 Wolfe(1977, p. 54)
# 253                            Smiley(oral comm.,1995)
# 254                                       Romero(1968)
# 255  Gee(1990) accepts Cookson and Eienack's(1967) ...
# 256                               Hofmann,Zetter(2001)
# 257      Gee(1990) accepts MeIntyre's(1965) occurrence
# 258                                       Floris(1964)
# 259                                 Efmov,Yarkov(1993)
# 260                                       Russel(1929)
# 261                                    Gasparini(1981)
#
#                                      SeeAlso
# 0                                        NaN
# 1         see also Gumati(1992),Mresah(1993)
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
# 5                                        NaN
# 6                                        NaN
# 7                                        NaN
# 8                                        NaN
# 9                                        NaN
# 10                                       NaN
# 11                                       NaN
# 12                                       NaN
# 13                                       NaN
# 14                                       NaN
# 15                                       NaN
# 16                                       NaN
# 17                                       NaN
# 18                                       NaN
# 19                                       NaN
# 20                                       NaN
# 21                                       NaN
# 22                                       NaN
# 23                                       NaN
# 24                                       NaN
# 25                                       NaN
# 26                                       NaN
# 27                                       NaN
# 28                                       NaN
# 29                                       NaN
# ..                                       ...
# 232                                      NaN
# 233  see also Sellwood,Sladen(1981, Fig. 20)
# 234                                      NaN
# 235                                      NaN
# 236                                      NaN
# 237                                      NaN
# 238                 see also Cleveland(1957)
# 239                                      NaN
# 240                                      NaN
# 241                                      NaN
# 242                                      NaN
# 243                                      NaN
# 244                                      NaN
# 245                                      NaN
# 246                                      NaN
# 247                                      NaN
# 248                                      NaN
# 249                                      NaN
# 250                                      NaN
# 251                   see also Daglian(1981)
# 252                                      NaN
# 253                                      NaN
# 254                                      NaN
# 255                                      NaN
# 256                                      NaN
# 257                                      NaN
# 258                                      NaN
# 259                                      NaN
# 260                                      NaN
# 261                                      NaN
#
# [262 rows x 21 columns]

# %% [markdown]
# There are a few ways to assign plateids, but the simplest ways generally involve putting the points into a feature collection and using the same partitioning function we used above on the.

# %%
# put the points into a feature collection, using Lat,Long coordinates from dataframe
point_features = []
for index,row in df.iterrows():
    point = pygplates.PointOnSphere(float(row.LAT),float(row.LONG))
    point_feature = pygplates.Feature()
    point_feature.set_geometry(point)
    point_features.append(point_feature)
    
# The partition points function can then be used as before
partitioned_point_features = pygplates.partition_into_plates(static_polygons,
                                                       rotation_model,
                                                       point_features) 

# Reconstruct the points to 60 Ma (in the Paleocene)
#reconstructed_point_features = []
pygplates.reconstruct(partitioned_point_features,
                      rotation_model,
                      '/tmp/reconstructed_points.shp',
                     60.0)  

coastlines_filename = 'Data/Seton_etal_ESR2012_Coastlines_2012.1_Polygon.gpmlz'
pygplates.reconstruct(coastlines_filename,
                      rotation_model,
                      '/tmp/reconstructed_coastlines.shp',
                     60.0)

# %% [markdown]
# Now we can plot the reconstructed points to see their distribution in the Paleocene

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.basemap import Basemap
from matplotlib.patches import Polygon

# %matplotlib inline

fig = plt.figure(figsize=(14,10))
ax_map = fig.add_axes([0,0,0.9,1.0])
m = Basemap(projection='robin', lon_0=0, resolution='c', ax=ax_map)

shp_info = m.readshapefile('/tmp/reconstructed_coastlines','shp',drawbounds=True,color='w')
    
for nshape,seg in enumerate(m.shp):
    poly = Polygon(seg,facecolor='khaki',edgecolor='k',alpha=0.7)
    ax_map.add_patch(poly)
    
m.readshapefile('/tmp/reconstructed_points', 'reconstructed_points')
 
for p in m.reconstructed_points:
    m.plot(p[0], p[1], marker='o', color='m', markersize=8, markeredgewidth=2)
    
plt.show()
# Out:
# /usr/local/lib/python2.7/dist-packages/mpl_toolkits/basemap/__init__.py:1707: MatplotlibDeprecationWarning: The axesPatch function was deprecated in version 2.1. Use Axes.patch instead.
#   if limb is not ax.axesPatch:
